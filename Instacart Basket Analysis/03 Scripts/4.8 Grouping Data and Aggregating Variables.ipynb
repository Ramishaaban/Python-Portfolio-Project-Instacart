# %% [markdown]
# # Step 1 of the task

# %% [markdown]
# ## Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data

# %%
path = r'C:\Users\ramis\OneDrive\JC\Data Analytics Course\Data Analytics Immersion\A4\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\ramis\\OneDrive\\JC\\Data Analytics Course\\Data Analytics Immersion\\A4\\Instacart Basket Analysis'

# %%
# import the orders_products_merged_2.pkl
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
# check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# create a subset of the firt million rows of the dataframe
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
df.groupby('product_name')

# %%
# group by department_id and agg on order_number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Performing Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Step 4 of the task: creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Aggregating Data with transform(): Split the data into groups, apply the transform() function, and create a new column, "max_order"
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
pd.options.display.max_rows = None

# %%
# Deriving Columns with loc() to create the loyalty_flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# checking frequency of the new "loyalty_flag" column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# check the output on specific columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# ### As discussed with my tutor, there are rows where the prices = 99999. They are row with product_id= 33664. I will change the values of the respective cells to 9.9 before I proceed further with the task of this exercise.

# %%
# Count the number of rows where product_id is equal to 33664
product_count = len(ords_prods_merge[ords_prods_merge['product_id'] == 33664])

# Count the total number of rows in the DataFrame
total_rows = len(ords_prods_merge)

# Calculate the percentage and round it to four decimal places
percentage = (product_count / total_rows) * 100
percentage_rounded = round(percentage, 4)

print("The percentage of rows where product_id = 33664 is", percentage_rounded, "%")
# Out:
# The percentage of rows where product_id = 33664 is 0.0022 %

# %%
# Update 'prices' where 'product_id' is 33664 to 9.9
ords_prods_merge.loc[ords_prods_merge['product_id'] == 33664, 'prices'] = 9.9

# %%
# verify the change in the max of prices as it was 99999
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
# checking rows where the product_id = 33664 by using the head() function
filtered_rows = ords_prods_merge[ords_prods_merge['product_id'] == 33664]
print(filtered_rows.head())
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 29165516    183964      873             3                   0
# 29165517   1851256      873             4                   6
# 29165518   1915696     1893             1                   5
# 29165519   2763293     1893             2                   4
# 29165520   2564805     1893             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 29165516                 10                     7.0       33664
# 29165517                 12                    13.0       33664
# 29165518                 17                     NaN       33664
# 29165519                 16                    13.0       33664
# 29165520                 17                    30.0       33664
#
#           add_to_cart_order  reordered           product_name  aisle_id  \
# 29165516                 11          0  2 % Reduced Fat  Milk        84
# ...

# %% [markdown]
# # Step 2 of the task

# %%
# create a panda object with the groupby() function
ords_prods_merge.groupby('product_name')

# %%
# group by department_id and agg order_number
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Step 3 of the task: to start with, the output of the entire dataframe contains the entire range of department_id's 1-21. In addition, the means, when computed for the entire dataset, exhibit lower variation compared to when calculated for a smaller subset.

# %% [markdown]
# # Step 5 of the task

# %%
# Group the data by 'loyalty_flag' and calculate basic statistics for 'prices'
loyalty_stats = ords_prods_merge.groupby('loyalty_flag')['prices'].describe()

# Print the statistics for each loyalty category
print(loyalty_stats)
# Out:
#                        count       mean         std  min  25%  50%   75%  \
# loyalty_flag
# Loyal customer    10284093.0   9.579352  164.031161  1.0  4.2  7.4  11.2
# New customer       6243990.0  10.059912  183.437157  1.0  4.2  7.4  11.3
# Regular customer  15876776.0   9.894716  176.730636  1.0  4.2  7.4  11.3
#
#                       max
# loyalty_flag
# Loyal customer    14900.0
# New customer      14900.0
# Regular customer  14900.0

# %% [markdown]
# ## the output above shows the the mean of prices for the three loyalty groups is almost the same. they are 9.57, 10.05 and 9.89 for Loyal customer, New customer, and Regular customer respectively. This suggests that the prices of products purchased by loyal customers do not  differ from those purchased by regular or new customers.

# %% [markdown]
# # Step 6 of the task

# %%
# Calculate the mean of prices for each user and create a new column 'avg_price'
ords_prods_merge['avg_price'] = ords_prods_merge.groupby('user_id')['prices'].transform('mean')

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Create a spending flag based on the average price
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
# checking frequency of the new "spending_flag" column
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31828060
# High spender      576799
# Name: count, dtype: int64

# %% [markdown]
# # Step 7 of the task

# %%
# Calculate the median of 'days_since_prior_order' for each user and create a new column 'median_days_since_prior_order'
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform('median')

# %%
# Create an order frequency flag based on the median
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
# checking frequency of the new "order_frequency_flag" column
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
# investigating order_frequency_flag with NaN values:
# Filter rows where 'order_frequency_flag' is NaN
rows_with_nan = ords_prods_merge[ords_prods_merge['order_frequency_flag'].isnull()]

# Print the filtered rows
print(rows_with_nan)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# ...

# %% [markdown]
# ### as per the output above, it seems that this user has only one order. Thus, we cannot calculate median_days_since_prior_order as there is only one single order. Therefore, we could consider updating the 5 respective NaN order_frequency_flag's to Non-frequent customer.

# %% [markdown]
# # Step 8 of the task: check done.

# %% [markdown]
# # Step 9 of the task

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_3.pkl'))
